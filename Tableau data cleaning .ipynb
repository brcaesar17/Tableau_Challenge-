# %%
import pandas as pd
from pathlib import Path

# %%
data_to_load3 = Path("Data/202311-citibike-tripdata.csv")

# %%
my_data3 = pd.read_csv(data_to_load3)
# Out:
# C:\Users\jojo\AppData\Local\Temp\ipykernel_7736\166694692.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   my_data3 = pd.read_csv(data_to_load3)

# %%
my_data3.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  48878C314260EF1D  classic_bike  2023-11-03 17:48:21  2023-11-03 17:58:46
# 1  9E0E1583031239C4  classic_bike  2023-11-01 12:54:59  2023-11-01 13:05:23
# 2  FEBB9109BCB32647  classic_bike  2023-11-13 12:23:29  2023-11-13 12:27:28
# 3  6E5C8C2B6D45B195  classic_bike  2023-11-27 08:49:26  2023-11-27 09:03:35
# 4  29175CDCC2735F4E  classic_bike  2023-11-14 19:20:04  2023-11-14 20:35:12
#
#                  start_station_name start_station_id      end_station_name  \
# 0  Queens Plaza North & Crescent St          6429.01  31 Ave & Steinway St
# 1  Queens Plaza North & Crescent St          6429.01       E 74 St & 1 Ave
# 2            E 128 St & Madison Ave          7735.23      E 138 St & 5 Ave
# 3       W 82 St & Central Park West          7304.08       E 74 St & 1 Ave
# 4                   8 Ave & W 33 St          6450.12                   NaN
#
# ...

# %%
data_to_load1 = Path("Data/202309-citibike-tripdata.csv")

# %%
my_data1 = pd.read_csv(data_to_load1)
# Out:
# C:\Users\jojo\AppData\Local\Temp\ipykernel_7736\1064190428.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   my_data1 = pd.read_csv(data_to_load1)

# %%
my_data1.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  B0A0F1DEFA4B72FC  electric_bike  2023-09-03 10:20:41  2023-09-03 10:24:16
# 1  2B26AB15647BF4EE   classic_bike  2023-09-27 15:44:23  2023-09-27 15:53:25
# 2  9D2B5971CA4E513F   classic_bike  2023-09-19 13:40:48  2023-09-19 13:48:11
# 3  17E6760596DC3ABE   classic_bike  2023-09-30 16:27:50  2023-09-30 16:56:35
# 4  97EFF376A7E2DC70   classic_bike  2023-09-21 16:59:53  2023-09-21 17:07:36
#
#           start_station_name start_station_id         end_station_name  \
# 0            E 1 St & Bowery          5636.13          E 10 St & 2 Ave
# 1  Pearl St & Hanover Square          4993.02  Allen St & Rivington St
# 2            E 1 St & Bowery          5636.13          E 10 St & 2 Ave
# 3    Central Ave & Himrod St          4713.01      Mott St & Prince St
# 4        St Marks Pl & 2 Ave          5669.10      Mott St & Prince St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
my_data1.describe
# Out:
# <bound method NDFrame.describe of                   ride_id  rideable_type           started_at  \
# 0        B0A0F1DEFA4B72FC  electric_bike  2023-09-03 10:20:41
# 1        2B26AB15647BF4EE   classic_bike  2023-09-27 15:44:23
# 2        9D2B5971CA4E513F   classic_bike  2023-09-19 13:40:48
# 3        17E6760596DC3ABE   classic_bike  2023-09-30 16:27:50
# 4        97EFF376A7E2DC70   classic_bike  2023-09-21 16:59:53
# ...                   ...            ...                  ...
# 3575157  472EFFA78D0FBCF2   classic_bike  2023-09-28 18:46:55
# 3575158  E986DA2AAB275937   classic_bike  2023-09-12 08:13:58
# 3575159  550CD10C7A00375E   classic_bike  2023-09-11 16:48:06
# 3575160  D4513B0A34BFD970   classic_bike  2023-09-07 07:42:11
# 3575161  12A14A1308892249   classic_bike  2023-09-22 13:04:02
#
#                     ended_at           start_station_name start_station_id  \
# 0        2023-09-03 10:24:16              E 1 St & Bowery          5636.13
# ...

# %%
my_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3575162 entries, 0 to 3575161
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 354.6+ MB

# %%
my_data1.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
my_data1.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
data_to_load2 = Path("Data/202310-citibike-tripdata.csv")

# %%
my_data2 = pd.read_csv(data_to_load2)
# Out:
# C:\Users\jojo\AppData\Local\Temp\ipykernel_7736\2635687966.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   my_data2 = pd.read_csv(data_to_load2)

# %%
my_data2.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  F01D2D54E9E60D6E  classic_bike  2023-10-03 02:48:38  2023-10-03 02:48:40
# 1  CAE4EDBEA07001BD  classic_bike  2023-10-11 16:03:17  2023-10-11 16:45:26
# 2  FDC34BAD31193E07  classic_bike  2023-10-11 19:57:13  2023-10-11 20:20:10
# 3  DFEA5E65AE91CE2A  classic_bike  2023-10-10 20:18:22  2023-10-10 20:18:37
# 4  48299D8BE9B55255  classic_bike  2023-10-17 16:26:58  2023-10-17 16:34:27
#
#                   start_station_name start_station_id  \
# 0         Columbus Pl & Atlantic Ave          4146.02
# 1        Central Park West & W 85 St          7354.01
# 2             Hicks St & Montague St          4645.09
# 3           Atlantic Ave & Furman St          4614.04
# 4  E 41 St & Madison Ave (SE corner)          6432.10
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0   Columbus Pl & Atlantic Ave        4146.02  40.677223 -73.922792
# ...

# %%
my_data2.count()
# Out:
# ride_id               3823673
# rideable_type         3823673
# started_at            3823673
# ended_at              3823673
# start_station_name    3817887
# start_station_id      3817887
# end_station_name      3808655
# end_station_id        3808655
# start_lat             3823673
# start_lng             3823673
# end_lat               3821286
# end_lng               3821286
# member_casual         3823673
# dtype: int64

# %%
my_data_merged1 = my_data2.append(my_data1,ignore_index=True)
# Out:
# C:\Users\jojo\AppData\Local\Temp\ipykernel_7736\3642600798.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_data_merged1 = my_data2.append(my_data1,ignore_index=True)

# %%
my_data_merged1.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  F01D2D54E9E60D6E  classic_bike  2023-10-03 02:48:38  2023-10-03 02:48:40
# 1  CAE4EDBEA07001BD  classic_bike  2023-10-11 16:03:17  2023-10-11 16:45:26
# 2  FDC34BAD31193E07  classic_bike  2023-10-11 19:57:13  2023-10-11 20:20:10
# 3  DFEA5E65AE91CE2A  classic_bike  2023-10-10 20:18:22  2023-10-10 20:18:37
# 4  48299D8BE9B55255  classic_bike  2023-10-17 16:26:58  2023-10-17 16:34:27
#
#                   start_station_name start_station_id  \
# 0         Columbus Pl & Atlantic Ave          4146.02
# 1        Central Park West & W 85 St          7354.01
# 2             Hicks St & Montague St          4645.09
# 3           Atlantic Ave & Furman St          4614.04
# 4  E 41 St & Madison Ave (SE corner)          6432.10
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0   Columbus Pl & Atlantic Ave        4146.02  40.677223 -73.922792
# ...

# %%
my_data_merged = my_data_merged1.append(my_data3,ignore_index=True)
# Out:
# C:\Users\jojo\AppData\Local\Temp\ipykernel_7736\4009134015.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_data_merged = my_data_merged1.append(my_data3,ignore_index=True)

# %%
my_data_merged.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  F01D2D54E9E60D6E  classic_bike  2023-10-03 02:48:38  2023-10-03 02:48:40
# 1  CAE4EDBEA07001BD  classic_bike  2023-10-11 16:03:17  2023-10-11 16:45:26
# 2  FDC34BAD31193E07  classic_bike  2023-10-11 19:57:13  2023-10-11 20:20:10
# 3  DFEA5E65AE91CE2A  classic_bike  2023-10-10 20:18:22  2023-10-10 20:18:37
# 4  48299D8BE9B55255  classic_bike  2023-10-17 16:26:58  2023-10-17 16:34:27
#
#                   start_station_name start_station_id  \
# 0         Columbus Pl & Atlantic Ave          4146.02
# 1        Central Park West & W 85 St          7354.01
# 2             Hicks St & Montague St          4645.09
# 3           Atlantic Ave & Furman St          4614.04
# 4  E 41 St & Madison Ave (SE corner)          6432.10
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0   Columbus Pl & Atlantic Ave        4146.02  40.677223 -73.922792
# ...

# %%
my_data_merged.count()
# Out:
# ride_id               10286572
# rideable_type         10286572
# started_at            10286572
# ended_at              10286572
# start_station_name    10275193
# start_station_id      10275193
# end_station_name      10247258
# end_station_id        10247258
# start_lat             10286572
# start_lng             10286572
# end_lat               10278890
# end_lng               10278890
# member_casual         10286572
# dtype: int64

# %%
# Save the dataframe to a CSV file
my_data_merged.to_csv('Data/citibike.csv')
